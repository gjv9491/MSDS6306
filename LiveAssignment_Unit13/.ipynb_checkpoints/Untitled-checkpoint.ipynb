# %% [markdown]
# ##### MSDS 6306: Introduction to Data Science (405) – Wednesday (6:30 pm)
# ##### Name: Gino Varghese
# ##### Live Assignment Unit 13
# ##### Due: November 28, 2016 (Tuesday)

# %%
my_list = [45.4,44.2,36.8,35.1,39.0,60.0,47.4,41.1,45.8,35.6]

# %%
print my_list
# Out:
#   File "<ipython-input-2-7b677187d0d9>", line 1
#     print my_list
#                 ^
# SyntaxError: Missing parentheses in call to 'print'

# %%
print(my_list)
# Out:
# [45.4, 44.2, 36.8, 35.1, 39.0, 60.0, 47.4, 41.1, 45.8, 35.6]

# %%
print(mylist[5])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-25b3d83c9092> in <module>()
# ----> 1 print(mylist[5])
#
# NameError: name 'mylist' is not defined

# %%
print my_list[5]
# Out:
#   File "<ipython-input-5-52906be397df>", line 1
#     print my_list[5]
#                 ^
# SyntaxError: Missing parentheses in call to 'print'

# %%
print my_list
# Out:
#   File "<ipython-input-1-7b677187d0d9>", line 1
#     print my_list
#                 ^
# SyntaxError: Missing parentheses in call to 'print'

# %%
mylist = [45.4,44.2,36.8,35.1,39.0,60.0,47.4,41.1,45.8,35.6]
print (mylist)
# Out:
# [45.4, 44.2, 36.8, 35.1, 39.0, 60.0, 47.4, 41.1, 45.8, 35.6]

# %%
mylist[5]
# Out:
# 60.0

# %%
print(mylist[4])
# Out:
# 39.0

# %%
mylist.append(55.2)
print(mylist)
# Out:
# [45.4, 44.2, 36.8, 35.1, 39.0, 60.0, 47.4, 41.1, 45.8, 35.6, 55.2]

# %%
mylist.remove(mylist[5])

# %%
print(mylist)
# Out:
# [45.4, 44.2, 36.8, 35.1, 39.0, 47.4, 41.1, 45.8, 35.6, 55.2]

# %%
for val in mylist:
    if val > 45:
        print("Value : %4.02f is greater than 45" % val)
# Out:
# Value : 45.40 is greater than 45
# Value : 47.40 is greater than 45
# Value : 45.80 is greater than 45
# Value : 55.20 is greater than 45

# %%
import numpy as np

# %%
myarray = np.array(mylist)

# %%
np.mean(myarray)
# Out:
# 42.560000000000002

# %%
np.std(myarray)
# Out:
# 5.9709630713981143

# %%
myarray[np.where(myarray < 45)]
# Out:
# array([ 44.2,  36.8,  35.1,  39. ,  41.1,  35.6])

# %%
np.max(my_array)
# Out:
# 55.200000000000003

# %%
np.min(my_array)
# Out:
# 35.100000000000001

# %%
import pandas as pd

# %%
iris = pd.read_csv("Analysis/Data/Iris.csv")

# %%
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris.drop('Id', axis=1)
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# 5              5.4           3.9            1.7           0.4     Iris-setosa
# 6              4.6           3.4            1.4           0.3     Iris-setosa
# 7              5.0           3.4            1.5           0.2     Iris-setosa
# 8              4.4           2.9            1.4           0.2     Iris-setosa
# 9              4.9           3.1            1.5           0.1     Iris-setosa
# 10             5.4           3.7            1.5           0.2     Iris-setosa
# ...

# %%
setosaspecies = iris[iris.Species == 'Iris-setosa' ]

# %%
setosaspecies.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
byspecies = iris.groupby('Species')

# %%
byspecies.describe()
# Out:
#                               Id  PetalLengthCm  PetalWidthCm  SepalLengthCm  \
# Species
# Iris-setosa     count   50.00000      50.000000     50.000000      50.000000
#                 mean    25.50000       1.464000      0.244000       5.006000
#                 std     14.57738       0.173511      0.107210       0.352490
#                 min      1.00000       1.000000      0.100000       4.300000
#                 25%     13.25000       1.400000      0.200000       4.800000
#                 50%     25.50000       1.500000      0.200000       5.000000
#                 75%     37.75000       1.575000      0.300000       5.200000
#                 max     50.00000       1.900000      0.600000       5.800000
# Iris-versicolor count   50.00000      50.000000     50.000000      50.000000
#                 mean    75.50000       4.260000      1.326000       5.936000
#                 std     14.57738       0.469911      0.197753       0.516171
# ...

# %%
# %matplotlib inline
bp = iris.boxplot(by='Species')

# %%
import seaborn as sns
sns.pairplot(iris,hue='Species')
